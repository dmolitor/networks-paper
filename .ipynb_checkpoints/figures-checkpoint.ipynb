# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import data
cz_flows = pd.read_csv("./data/opp_migration_with_features.csv")

# %%
cz_flows.head()
# Out:
#     o_cz  d_cz    n  n_tot_o  n_tot_d  o_d_distance  o_census_2000_population  \
# 0   6502   100  127    22148    56915    233.396750                    203077
# 1  34108   100    0     1702    56915   5586.842924                     13913
# 2  10302   100   16    26182    56915    647.238506                    223605
# 3   5201   100    1     6530    56915    633.004265                     54214
# 4  29201   100    0     2794    56915   1229.687706                     21441
#
#    o_urban_areas  o_frac_black  o_racial_segregation  ...  \
# 0              1      0.032919              0.074607  ...
# 1              0      0.009272              0.075959  ...
# 2              1      0.212549              0.142392  ...
# 3              1      0.184620              0.087787  ...
# 4              0      0.009888              0.114814  ...
#
#    d_migration_inflow_rate  d_migration_outlflow_rate  d_frac_foreign_born  \
# 0                  0.00564                   0.004697             0.011784
# 1                  0.00564                   0.004697             0.011784
# 2                  0.00564                   0.004697             0.011784
# 3                  0.00564                   0.004697             0.011784
# 4                  0.00564                   0.004697             0.011784
#
#    d_social_capital_index  d_fraction_religious  d_violent_crime_rate  \
# 0               -0.297858              0.514403              0.001409
# 1               -0.297858              0.514403              0.001409
# 2               -0.297858              0.514403              0.001409
# 3               -0.297858              0.514403              0.001409
# 4               -0.297858              0.514403              0.001409
#
#    d_fraction_of_children_with_single_mothers  d_fraction_of_adults_divorced  \
# 0                                    0.189803                       0.110173
# 1                                    0.189803                       0.110173
# 2                                    0.189803                       0.110173
# 3                                    0.189803                       0.110173
# 4                                    0.189803                       0.110173
#
#    d_fraction_of_adults_married  d_income_growth_2000_2006_10
# 0                      0.600893                     -0.002278
# 1                      0.600893                     -0.002278
# 2                      0.600893                     -0.002278
# 3                      0.600893                     -0.002278
# 4                      0.600893                     -0.002278
#
# [5 rows x 82 columns]

# %%
cz_flows.describe()
# Out:
#                 o_cz           d_cz             n       n_tot_o       n_tot_d  \
# count  549081.000000  549081.000000  5.490810e+05  5.490810e+05  5.490810e+05
# mean    22443.815115   22443.815115  5.722583e+01  4.242170e+04  4.242170e+04
# std     11118.039576   11118.039576  3.263886e+03  1.098934e+05  1.116513e+05
# min       100.000000     100.000000 -2.000000e+00  1.210000e+02  1.220000e+02
# 25%     12701.000000   12701.000000  0.000000e+00  4.460000e+03  3.611000e+03
# 50%     26106.000000   26106.000000  0.000000e+00  1.189300e+04  1.043900e+04
# 75%     31301.000000   31301.000000  3.000000e+00  3.383400e+04  3.263000e+04
# max     39400.000000   39400.000000  1.400000e+06  1.755308e+06  1.713298e+06
#
#         o_d_distance  o_census_2000_population  o_urban_areas   o_frac_black  \
# count  549081.000000              5.490810e+05  549081.000000  549081.000000
# mean     1625.009891              3.797866e+05       0.438596       0.077820
# std      1147.378119              1.046520e+06       0.496216       0.122141
# min         0.000000              1.193000e+03       0.000000       0.000000
# 25%       859.808480              3.838400e+04       0.000000       0.003507
# 50%      1384.468366              1.038420e+05       0.000000       0.021859
# 75%      2045.681401              2.898490e+05       1.000000       0.082248
# max      8444.130876              1.639336e+07       1.000000       0.658326
#
#        o_racial_segregation  ...  d_migration_inflow_rate  \
# count         549081.000000  ...            549081.000000
# mean               0.129757  ...                 0.016477
# std                0.099990  ...                 0.010299
# min                0.000000  ...                 0.000000
# 25%                0.056115  ...                 0.009825
# 50%                0.107352  ...                 0.014167
# 75%                0.180903  ...                 0.020788
# max                0.553745  ...                 0.077018
#
#        d_migration_outlflow_rate  d_frac_foreign_born  d_social_capital_index  \
# count              549081.000000        549081.000000           549081.000000
# mean                    0.016795             0.041163                0.168877
# std                     0.007503             0.050387                1.277856
# min                     0.000000             0.000000               -3.198993
# 25%                     0.011938             0.012375               -0.757008
# 50%                     0.015540             0.024069                0.063928
# 75%                     0.020399             0.046056                0.932727
# max                     0.052476             0.396842                7.305450
#
#        d_fraction_religious  d_violent_crime_rate  \
# count         549081.000000         549081.000000
# mean               0.545552              0.001571
# std                0.167047              0.001408
# min                0.110493              0.000000
# 25%                0.424567              0.000846
# 50%                0.524668              0.001351
# 75%                0.643264              0.001935
# max                1.308379              0.027579
#
#        d_fraction_of_children_with_single_mothers  \
# count                               549081.000000
# mean                                     0.201726
# std                                      0.052975
# min                                      0.081761
# 25%                                      0.170597
# 50%                                      0.196327
# 75%                                      0.226241
# max                                      0.433681
#
#        d_fraction_of_adults_divorced  d_fraction_of_adults_married  \
# count                  549081.000000                 549081.000000
# mean                        0.096649                      0.574457
# std                         0.017939                      0.046844
# min                         0.039504                      0.372919
# 25%                         0.084618                      0.545405
# 50%                         0.097997                      0.579520
# 75%                         0.108558                      0.606677
# max                         0.190349                      0.694725
#
#        d_income_growth_2000_2006_10
# count                 549081.000000
# mean                      -0.001675
# std                        0.012193
# min                       -0.118081
# 25%                       -0.007715
# 50%                       -0.002401
# 75%                        0.004093
# max                        0.045762
#
# [8 rows x 82 columns]

# %%
var_importance = pd.read_csv("./data/var_importance.csv")

# %%
# import sys
# sys.executable
# !{sys.executable} -m pip install geojson
# Out:
# Collecting geojson
#   Using cached geojson-3.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.0.1
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import geojson
with open("./data/cz_cpc_measures.geojson") as f:
    gj = geojson.load(f)

# %%
perf = pd.DataFrame([x['properties'] for x in gj['features']])
perf.head()
# Out:
#    tile_ID commuting_zone_name           state  population  tot_outflow  \
# 0    100.0        Johnson City       Tennessee       57198        14370
# 1  10000.0         Panama City         Florida       19631         7901
# 2   1001.0               Boone  North Carolina        6397         2979
# 3   1002.0           Morganton  North Carolina       16767         6451
# 4  10101.0          Bainbridge         Georgia        5045         2191
#
#    gravity_cpc  rad_cpc  gravity_rmse    rad_rmse   rf_cpc    rf_rmse
# 0      0.23508  0.11520     73.550607  124.612205  0.37319  61.686294
# 1      0.40473  0.16516     21.852901   50.929047  0.40228  24.636573
# 2      0.33425  0.19086      8.192982   26.879433  0.37627  12.991343
# 3      0.29494  0.16757     21.801619   53.949721  0.38054  34.019543
# 4      0.33682  0.11779      6.238866   29.270642  0.36792  16.763620

# %%
perf[perf['state'] == 'New York']
# Out:
#      tile_ID commuting_zone_name     state  population  tot_outflow  \
# 102  16500.0                Erie  New York       74002        25567
# 121  17700.0            Syracuse  New York      125184        39160
# 122  17800.0             Oneonta  New York       18611         8622
# 123  17900.0               Union  New York       33438        13289
# 125  18000.0             Buffalo  New York      273198        65727
# 126  18100.0              Elmira  New York       37491        15364
# 127  18201.0               Olean  New York       23187        10265
# 129  18300.0           Watertown  New York       27353        10596
# 130  18400.0         Plattsburgh  New York       18600         6308
# 131  18500.0           Amsterdam  New York       12972         5186
# 132  18600.0              Albany  New York      119831        36048
# 140  19300.0        Poughkeepsie  New York      106209        41486
# 141  19400.0            New York  New York     1008604       215432
#
#      gravity_cpc  rad_cpc  gravity_rmse     rad_rmse   rf_cpc      rf_rmse  \
# 102      0.31638  0.11816     91.527665   161.929889  0.37849   117.338757
# 121      0.29120  0.16661    156.878543   251.702206  0.40607   118.778430
# 122      0.34880  0.19755     23.673414    56.280928  0.39327    31.180187
# 123      0.34600  0.16330     40.951417    90.029954  0.38036    44.609298
# 125      0.22889  0.10065    352.317139   492.366721  0.34777   407.439736
# 126      0.35740  0.18347     45.554656    92.564378  0.39944    48.446898
# 127      0.34469  0.23062     29.299595    59.679814  0.37795    59.510266
# 129      0.31736  0.17123     34.647773    67.162393  0.39233    33.901354
# 130      0.28697  0.13767     23.680162    56.212042  0.37180    37.733539
# 131      0.29524  0.23211     17.009447    46.162252  0.36396    36.464052
# 132      0.29369  0.12522    148.245614   252.914657  0.40684   115.825643
# 140      0.36820  0.11951    125.630229   256.926877  0.37850   211.392129
# 141      0.21071  0.17823   1303.427800  1466.274052  0.25293  4445.648272
#
#       o_cz  urban
# 102  16500      1
# 121  17700      1
# 122  17800      0
# 123  17900      1
# 125  18000      1
# 126  18100      1
# 127  18201      0
# 129  18300      1
# 130  18400      0
# 131  18500      0
# 132  18600      1
# 140  19300      1
# 141  19400      1

# %%
urban = cz_flows[['o_cz', 'o_urban_areas']].drop_duplicates()
urban = urban.rename({"o_urban_areas": "urban"}, axis=1)
perf = perf.merge(urban, left_on='tile_ID', right_on='o_cz')

# %%
perf.groupby(['urban']).size()
# Out:
# urban
# 0    416
# 1    325
# dtype: int64

# %%
perf['rf-gravity'] = perf['rf_cpc'] - perf['gravity_cpc']

# %%
order= perf.groupby("state")['rf-gravity'].mean().sort_values(ascending=False).index

# %%
plt.figure(figsize=(5,10))
ax = sns.barplot(data=perf, y='state', x='rf-gravity', order=order)
ax.set_xlabel("rf-gravity cpc")
plt.savefig("rf-gravity_cpc.png", bbox_inches='tight')

# %%
## feature importance
var_importance = pd.read_csv("./data/var_importance.csv")
var_importance_top10 = var_importance.iloc[:10]
variable_recoded = [
    "Distance between origin and destination",
    "Origin population",
    "Destination fraction foreign born",
    "Destination population",
    "Destination income segregation",
    "Origin income segregation",
    "Origin student-teacher ratio in public schools",
    "Destination student-teacher ratio in public schools",
    "Destination violent crime rate",
    "Origin income-adjusted standardized test scores"
]
var_importance_top10.insert(0, "predictor", variable_recoded)

# %%
ax = sns.barplot(data=var_importance_top10, y='predictor', x='importance')
ax.set_xlabel("feature importance")
ax.set_ylabel("")
plt.savefig("./figures/rf-feature_importance.png", bbox_inches='tight')
# Out:
# Text(0, 0.5, '')

# %%
var_to_readable = {
    "o_d_distance": "distance",
    "n_tot_o": "total_outflow",
    "d_frac_foreign_born": ""
}
var['variable'].apply(lambda r: )
# Out:
#                                       variable  importance
# 0                                 o_d_distance    0.290528
# 1                                      n_tot_o    0.052045
# 2                          d_frac_foreign_born    0.048698
# 3                                      n_tot_d    0.033461
# 4               d_segregation_of_affluence_p75    0.027685
# ..                                         ...         ...
# 72  o_fraction_of_children_with_single_mothers    0.002043
# 73                   o_migration_outlflow_rate    0.002024
# 74                       d_state_eitc_exposure    0.001153
# 75                               o_urban_areas    0.000304
# 76                               d_urban_areas    0.000276
#
# [77 rows x 2 columns]
